# %%
#..Load modules
import os
import sys
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
from plotnine import *
from output_gradcatch import Output
from utility import export

# %% [markdown]
# ## Cellulose plots

# %% [markdown]
# ### Open the pickled output

# %%
SP01 = pd.read_pickle('C:/luciana_datos/UCI/Project_14 (Anna)/DEMENT_gradcatch/DEMENT/output_cellulose/SP01_results_cellulose.pkl')

# %%
SP02 = pd.read_pickle('C:/luciana_datos/UCI/Project_14 (Anna)/DEMENT_gradcatch/DEMENT/output_cellulose/SP02_results_cellulose.pkl')

# %%
SP03 = pd.read_pickle('C:/luciana_datos/UCI/Project_14 (Anna)/DEMENT_gradcatch/DEMENT/output_cellulose/SP03_results_cellulose.pkl')

# %%
SP04 = pd.read_pickle('C:/luciana_datos/UCI/Project_14 (Anna)/DEMENT_gradcatch/DEMENT/output_cellulose/SP04_results_cellulose.pkl')

# %%
SP05 = pd.read_pickle('C:/luciana_datos/UCI/Project_14 (Anna)/DEMENT_gradcatch/DEMENT/output_cellulose/SP05_results_cellulose.pkl')

# %% [markdown]
# ### Respiration

# %%
tt        = np.linspace(0,9,10) # Number of repetitions = 10
time      = np.linspace(0,365*4,365*4+1)

# %%
SP01_res = []
SP02_res = []
SP03_res = []
SP04_res = []
SP05_res = []

for i in tt:
        SP01_res.append(SP01[int(i)].RespSeries)
        SP02_res.append(SP02[int(i)].RespSeries)
        SP03_res.append(SP03[int(i)].RespSeries)
        SP04_res.append(SP04[int(i)].RespSeries)
        SP05_res.append(SP05[int(i)].RespSeries)

# %%
Respi_mean_SP01  = (np.array(SP01_res).mean(axis=0))/10000
Respi_5_SP01     = np.percentile(SP01_res,5,axis=0)/10000
Respi_95_SP01    = np.percentile(SP01_res,95,axis=0)/10000
Respi_mean_SP02  = (np.array(SP02_res).mean(axis=0))/10000
Respi_5_SP02     = np.percentile(SP02_res,5,axis=0)/10000
Respi_95_SP02    = np.percentile(SP02_res,95,axis=0)/10000
Respi_mean_SP03  = (np.array(SP03_res).mean(axis=0))/10000
Respi_5_SP03     = np.percentile(SP03_res,5,axis=0)/10000
Respi_95_SP03    = np.percentile(SP03_res,95,axis=0)/10000
Respi_mean_SP04  = (np.array(SP04_res).mean(axis=0))/10000
Respi_5_SP04     = np.percentile(SP04_res,5,axis=0)/10000
Respi_95_SP04    = np.percentile(SP04_res,95,axis=0)/10000
Respi_mean_SP05  = (np.array(SP05_res).mean(axis=0))/10000
Respi_5_SP05     = np.percentile(SP05_res,5,axis=0)/10000
Respi_95_SP05    = np.percentile(SP05_res,95,axis=0)/10000

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row', figsize = (6,3), dpi = 140)
ax[0,0].fill_between(time,Respi_5_SP01,Respi_95_SP01, alpha=.5, linewidth=0,label="95% CI")
ax[0,0].plot(time,Respi_mean_SP01, linewidth=2,label="Mean")
ax[0,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,0].set_ylim([0, 2])
ax[0,0].set_title('SP1')
ax[0,1].fill_between(time,Respi_5_SP02,Respi_95_SP02, alpha=.5, linewidth=0,label="95% CI")
ax[0,1].plot(time,Respi_mean_SP02, linewidth=2,label="Mean")
ax[0,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,1].set_ylim([0, 2])
ax[0,1].set_title('SP2')
ax[0,2].fill_between(time,Respi_5_SP03,Respi_95_SP03, alpha=.5, linewidth=0,label="95% CI")
ax[0,2].plot(time,Respi_mean_SP03, linewidth=2,label="Mean")
ax[0,2].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,2].set_ylim([0, 2])
ax[0,2].set_title('SP3')
ax[1,0].fill_between(time,Respi_5_SP04,Respi_95_SP04, alpha=.5, linewidth=0,label="95% CI")
ax[1,0].plot(time,Respi_mean_SP04, linewidth=2,label="Mean")
ax[1,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,0].set_ylim([0, 2])
ax[1,0].set_title('SP4')
ax[1,1].fill_between(time,Respi_5_SP05,Respi_95_SP05, alpha=.5, linewidth=0,label="95% CI")
ax[1,1].plot(time,Respi_mean_SP05, linewidth=2,label="Mean")
ax[1,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,1].set_ylim([0, 2])
ax[1,1].set_title('SP5')
fig.text(0.5, -0.02, 'Time (d)', ha='center', va='center')
fig.text(0.06, 0.5, 'Respiration ($mg$ $cm^{-3}$)', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.06, 0.5, 'Respiration ($mg$ $cm^{-3}$)')

# %% [markdown]
# ### Substrate

# %%
SP01_subst = []
SP02_subst = []
SP03_subst = []
SP04_subst = []
SP05_subst = []

for i in tt:
        SP01_subst.append(SP01[int(i)].SubstratesSeries.T["Cellulose"])
        SP02_subst.append(SP02[int(i)].SubstratesSeries.T["Cellulose"])
        SP03_subst.append(SP03[int(i)].SubstratesSeries.T["Cellulose"])
        SP04_subst.append(SP04[int(i)].SubstratesSeries.T["Cellulose"])
        SP05_subst.append(SP05[int(i)].SubstratesSeries.T["Cellulose"])

# %%
Sub_mean_SP01  = (np.array(SP01_subst).mean(axis=0))/10000
Sub_5_SP01     = np.percentile(SP01_subst,5,axis=0)/10000
Sub_95_SP01    = np.percentile(SP01_subst,95,axis=0)/10000
Sub_mean_SP02  = (np.array(SP02_subst).mean(axis=0))/10000
Sub_5_SP02     = np.percentile(SP02_subst,5,axis=0)/10000
Sub_95_SP02    = np.percentile(SP02_subst,95,axis=0)/10000
Sub_mean_SP03  = (np.array(SP03_subst).mean(axis=0))/10000
Sub_5_SP03     = np.percentile(SP03_subst,5,axis=0)/10000
Sub_95_SP03    = np.percentile(SP03_subst,95,axis=0)/10000
Sub_mean_SP04  = (np.array(SP04_subst).mean(axis=0))/10000
Sub_5_SP04     = np.percentile(SP04_subst,5,axis=0)/10000
Sub_95_SP04    = np.percentile(SP04_subst,95,axis=0)/10000
Sub_mean_SP05  = (np.array(SP05_subst).mean(axis=0))/10000
Sub_5_SP05     = np.percentile(SP05_subst,5,axis=0)/10000
Sub_95_SP05    = np.percentile(SP05_subst,95,axis=0)/10000

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row', figsize = (6,3), dpi = 140)
ax[0,0].fill_between(time,Sub_5_SP01,Sub_95_SP01, alpha=.5, linewidth=0,label="95% CI")
ax[0,0].plot(time,Sub_mean_SP01, linewidth=2,label="Mean")
ax[0,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,0].set_ylim([0, 350])
ax[0,0].set_title('SP1')
ax[0,1].fill_between(time,Sub_5_SP02,Sub_95_SP02, alpha=.5, linewidth=0,label="95% CI")
ax[0,1].plot(time,Sub_mean_SP02, linewidth=2,label="Mean")
ax[0,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,1].set_ylim([0, 350])
ax[0,1].set_title('SP2')
ax[0,2].fill_between(time,Sub_5_SP03,Sub_95_SP03, alpha=.5, linewidth=0,label="95% CI")
ax[0,2].plot(time,Sub_mean_SP03, linewidth=2,label="Mean")
ax[0,2].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,2].set_ylim([0, 350])
ax[0,2].set_title('SP3')
ax[1,0].fill_between(time,Sub_5_SP04,Sub_95_SP04, alpha=.5, linewidth=0,label="95% CI")
ax[1,0].plot(time,Sub_mean_SP04, linewidth=2,label="Mean")
ax[1,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,0].set_ylim([0, 350])
ax[1,0].set_title('SP4')
ax[1,1].fill_between(time,Sub_5_SP05,Sub_95_SP05, alpha=.5, linewidth=0,label="95% CI")
ax[1,1].plot(time,Sub_mean_SP05, linewidth=2,label="Mean")
ax[1,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,1].set_ylim([0, 350])
ax[1,1].set_title('SP5')
fig.text(0.5, -0.02, 'Time (d)', ha='center', va='center')
fig.text(0.06, 0.5, 'Total substrate concentration ($mg$ $cm^{-3}$)', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.06, 0.5, 'Total substrate concentration ($mg$ $cm^{-3}$)')

# %% [markdown]
# ### Substrate loss (%)

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row', figsize = (6,3), dpi = 140)
ax[0,0].fill_between(time,(Sub_5_SP01[0]-Sub_5_SP01)*100/Sub_5_SP01[0],(Sub_95_SP01[0]-Sub_95_SP01)*100/Sub_95_SP01[0], alpha=.5, linewidth=0,label="95% CI")
ax[0,0].plot(time,(Sub_mean_SP01[0]-Sub_mean_SP01)*100/Sub_mean_SP01[0], linewidth=2,label="Mean")
ax[0,0].plot(365*3, 95, marker=(5, 2), markersize=5, markeredgecolor="red", markerfacecolor="red")
ax[0,0].plot(365*4, 97.5, marker=(5, 2), markersize=5, markeredgecolor="black", markerfacecolor="black")
ax[0,0].set_ylim([0, 100])
ax[0,0].set_title('SP1')
ax[0,1].fill_between(time,(Sub_5_SP02[0]-Sub_5_SP02)*100/Sub_5_SP02[0],(Sub_95_SP02[0]-Sub_95_SP02)*100/Sub_95_SP02[0], alpha=.5, linewidth=0,label="95% CI")
ax[0,1].plot(time,(Sub_mean_SP02[0]-Sub_mean_SP02)*100/Sub_mean_SP02[0], linewidth=2,label="Mean")
ax[0,1].plot(365*3, 75, marker=(5, 2), markersize=5, markeredgecolor="red", markerfacecolor="red")
ax[0,1].plot(365*4, 88, marker=(5, 2), markersize=5, markeredgecolor="black", markerfacecolor="black")
ax[0,1].set_ylim([0, 100])
ax[0,1].set_title('SP2')
ax[0,2].fill_between(time,(Sub_5_SP03[0]-Sub_5_SP03)*100/Sub_5_SP03[0],(Sub_95_SP03[0]-Sub_95_SP03)*100/Sub_95_SP03[0], alpha=.5, linewidth=0,label="95% CI")
ax[0,2].plot(time,(Sub_mean_SP03[0]-Sub_mean_SP03)*100/Sub_mean_SP03[0], linewidth=2,label="Mean")
ax[0,2].plot(365*3, 88, marker=(5, 2), markersize=5, markeredgecolor="red", markerfacecolor="red")
ax[0,2].plot(365*4, 76, marker=(5, 2), markersize=5, markeredgecolor="black", markerfacecolor="black")
ax[0,2].set_ylim([0, 100])
ax[0,2].set_title('SP3')
ax[1,0].fill_between(time,(Sub_5_SP04[0]-Sub_5_SP04)*100/Sub_5_SP04[0],(Sub_95_SP04[0]-Sub_95_SP04)*100/Sub_95_SP04[0], alpha=.5, linewidth=0,label="95% CI")
ax[1,0].plot(time,(Sub_mean_SP04[0]-Sub_mean_SP04)*100/Sub_mean_SP04[0], linewidth=2,label="Mean")
ax[1,0].plot(365*3, 64, marker=(5, 2), markersize=5, markeredgecolor="red", markerfacecolor="red")
ax[1,0].plot(365*4, 52, marker=(5, 2), markersize=5, markeredgecolor="black", markerfacecolor="black")
ax[1,0].set_ylim([0, 100])
ax[1,0].set_title('SP4')
ax[1,1].fill_between(time,(Sub_5_SP05[0]-Sub_5_SP05)*100/Sub_5_SP05[0],(Sub_95_SP05[0]-Sub_95_SP05)*100/Sub_95_SP04[0], alpha=.5, linewidth=0,label="95% CI")
ax[1,1].plot(time,(Sub_mean_SP05[0]-Sub_mean_SP05)*100/Sub_mean_SP05[0], linewidth=2,label="Mean")
ax[1,1].plot(365*4, 39, marker=(5, 2), markersize=5, markeredgecolor="red", markerfacecolor="red")
ax[1,1].set_ylim([0, 100])
ax[1,1].set_title('SP5')
fig.text(0.5, -0.02, 'Time (d)', ha='center', va='center')
fig.text(0.06, 0.5, 'Mass Loss (%)', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.06, 0.5, 'Mass Loss (%)')

# %% [markdown]
# ### CUE

# %%
SP01_cue = []
SP02_cue = []
SP03_cue = []
SP04_cue = []
SP05_cue = []

for i in tt:
        SP01_cue.append(SP01[int(i)].CUE_system)
        SP02_cue.append(SP02[int(i)].CUE_system)
        SP03_cue.append(SP03[int(i)].CUE_system)
        SP04_cue.append(SP04[int(i)].CUE_system)
        SP05_cue.append(SP05[int(i)].CUE_system)

# %%
Sub_mean_SP01  = (np.array(SP01_cue).mean(axis=0))
Sub_5_SP01     = np.percentile(SP01_cue,5,axis=0)
Sub_95_SP01    = np.percentile(SP01_cue,95,axis=0)
Sub_mean_SP02  = (np.array(SP02_cue).mean(axis=0))
Sub_5_SP02     = np.percentile(SP02_cue,5,axis=0)
Sub_95_SP02    = np.percentile(SP02_cue,95,axis=0)
Sub_mean_SP03  = (np.array(SP03_cue).mean(axis=0))
Sub_5_SP03     = np.percentile(SP03_cue,5,axis=0)
Sub_95_SP03    = np.percentile(SP03_cue,95,axis=0)
Sub_mean_SP04  = (np.array(SP04_cue).mean(axis=0))
Sub_5_SP04     = np.percentile(SP04_cue,5,axis=0)
Sub_95_SP04    = np.percentile(SP04_cue,95,axis=0)
Sub_mean_SP05  = (np.array(SP05_cue).mean(axis=0))
Sub_5_SP05     = np.percentile(SP05_cue,5,axis=0)
Sub_95_SP05    = np.percentile(SP05_cue,95,axis=0)

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row', figsize = (6,3), dpi = 140)
ax[0,0].fill_between(time,Sub_5_SP01,Sub_95_SP01, alpha=.5, linewidth=0,label="95% CI")
ax[0,0].plot(time,Sub_mean_SP01, linewidth=2,label="Mean")
ax[0,0].set_title('SP1')
ax[0,1].fill_between(time,Sub_5_SP02,Sub_95_SP02, alpha=.5, linewidth=0,label="95% CI")
ax[0,1].plot(time,Sub_mean_SP02, linewidth=2,label="Mean")
ax[0,1].set_title('SP2')
ax[0,2].fill_between(time,Sub_5_SP03,Sub_95_SP03, alpha=.5, linewidth=0,label="95% CI")
ax[0,2].plot(time,Sub_mean_SP03, linewidth=2,label="Mean")
ax[0,2].set_title('SP3')
ax[1,0].fill_between(time,Sub_5_SP04,Sub_95_SP04, alpha=.5, linewidth=0,label="95% CI")
ax[1,0].plot(time,Sub_mean_SP04, linewidth=2,label="Mean")
ax[1,0].set_title('SP4')
ax[1,1].fill_between(time,Sub_5_SP05,Sub_95_SP05, alpha=.5, linewidth=0,label="95% CI")
ax[1,1].plot(time,Sub_mean_SP05, linewidth=2,label="Mean")
ax[1,1].set_title('SP5')
fig.text(0.5, -0.02, 'Time (d)', ha='center', va='center')
fig.text(0.06, 0.5, 'CUE', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.06, 0.5, 'CUE')

# %% [markdown]
# ### Microbial biomass

# %%
SP01_bio = []
SP02_bio = []
SP03_bio = []
SP04_bio = []
SP05_bio = []

for i in tt:
        SP01_bio.append((SP01[int(i)].MicrobesSeries).sum(axis=0))
        SP02_bio.append((SP02[int(i)].MicrobesSeries).sum(axis=0))
        SP03_bio.append((SP03[int(i)].MicrobesSeries).sum(axis=0))
        SP04_bio.append((SP04[int(i)].MicrobesSeries).sum(axis=0))
        SP05_bio.append((SP05[int(i)].MicrobesSeries).sum(axis=0))

# %%
Sub_mean_SP01  = (np.array(SP01_bio).mean(axis=0))/10000
Sub_5_SP01     = np.percentile(SP01_bio,5,axis=0)/10000
Sub_95_SP01    = np.percentile(SP01_bio,95,axis=0)/10000
Sub_mean_SP02  = (np.array(SP02_bio).mean(axis=0))/10000
Sub_5_SP02     = np.percentile(SP02_bio,5,axis=0)/10000
Sub_95_SP02    = np.percentile(SP02_bio,95,axis=0)/10000
Sub_mean_SP03  = (np.array(SP03_bio).mean(axis=0))/10000
Sub_5_SP03     = np.percentile(SP03_bio,5,axis=0)/10000
Sub_95_SP03    = np.percentile(SP03_bio,95,axis=0)/10000
Sub_mean_SP04  = (np.array(SP04_bio).mean(axis=0))/10000
Sub_5_SP04     = np.percentile(SP04_bio,5,axis=0)/10000
Sub_95_SP04    = np.percentile(SP04_bio,95,axis=0)/10000
Sub_mean_SP05  = (np.array(SP05_bio).mean(axis=0))/10000
Sub_5_SP05     = np.percentile(SP05_bio,5,axis=0)/10000
Sub_95_SP05    = np.percentile(SP05_bio,95,axis=0)/10000

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row', figsize = (6,3), dpi = 140)
ax[0,0].fill_between(time,Sub_5_SP01,Sub_95_SP01, alpha=.5, linewidth=0,label="95% CI")
ax[0,0].plot(time,Sub_mean_SP01, linewidth=2,label="Mean")
ax[0,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,0].set_ylim([0, 25])
ax[0,0].set_title('SP1')
ax[0,1].fill_between(time,Sub_5_SP02,Sub_95_SP02, alpha=.5, linewidth=0,label="95% CI")
ax[0,1].plot(time,Sub_mean_SP02, linewidth=2,label="Mean")
ax[0,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,1].set_ylim([0, 25])
ax[0,1].set_title('SP2')
ax[0,2].fill_between(time,Sub_5_SP03,Sub_95_SP03, alpha=.5, linewidth=0,label="95% CI")
ax[0,2].plot(time,Sub_mean_SP03, linewidth=2,label="Mean")
ax[0,2].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,2].set_ylim([0, 25])
ax[0,2].set_title('SP3')
ax[1,0].fill_between(time,Sub_5_SP04,Sub_95_SP04, alpha=.5, linewidth=0,label="95% CI")
ax[1,0].plot(time,Sub_mean_SP04, linewidth=2,label="Mean")
ax[1,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,0].set_ylim([0, 25])
ax[1,0].set_title('SP4')
ax[1,1].fill_between(time,Sub_5_SP05,Sub_95_SP05, alpha=.5, linewidth=0,label="95% CI")
ax[1,1].plot(time,Sub_mean_SP05, linewidth=2,label="Mean")
ax[1,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,1].set_ylim([0, 25])
ax[1,1].set_title('SP5')
fig.text(0.5, -0.02, 'Time (d)', ha='center', va='center')
fig.text(0.06, 0.5, 'Microbial Biomass ($mg$ $cm^{-3}$)', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.06, 0.5, 'Microbial Biomass ($mg$ $cm^{-3}$)')

# %% [markdown]
# ### NH4

# %%
SP01_cue = []
SP02_cue = []
SP03_cue = []
SP04_cue = []
SP05_cue = []

for i in tt:
        SP01_cue.append(SP01[int(i)].NH4Series)
        SP02_cue.append(SP02[int(i)].NH4Series)
        SP03_cue.append(SP03[int(i)].NH4Series)
        SP04_cue.append(SP04[int(i)].NH4Series)
        SP05_cue.append(SP05[int(i)].NH4Series)

# %%
Sub_mean_SP01  = (np.array(SP01_cue).mean(axis=0))/10000
Sub_5_SP01     = np.percentile(SP01_cue,5,axis=0)/10000
Sub_95_SP01    = np.percentile(SP01_cue,95,axis=0)/10000
Sub_mean_SP02  = (np.array(SP02_cue).mean(axis=0))/10000
Sub_5_SP02     = np.percentile(SP02_cue,5,axis=0)/10000
Sub_95_SP02    = np.percentile(SP02_cue,95,axis=0)/10000
Sub_mean_SP03  = (np.array(SP03_cue).mean(axis=0))/10000
Sub_5_SP03     = np.percentile(SP03_cue,5,axis=0)/10000
Sub_95_SP03    = np.percentile(SP03_cue,95,axis=0)/10000
Sub_mean_SP04  = (np.array(SP04_cue).mean(axis=0))/10000
Sub_5_SP04     = np.percentile(SP04_cue,5,axis=0)/10000
Sub_95_SP04    = np.percentile(SP04_cue,95,axis=0)/10000
Sub_mean_SP05  = (np.array(SP05_cue).mean(axis=0))/10000
Sub_5_SP05     = np.percentile(SP05_cue,5,axis=0)/10000
Sub_95_SP05    = np.percentile(SP05_cue,95,axis=0)/10000

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row', figsize = (6,3), dpi = 140)
ax[0,0].fill_between(time,Sub_5_SP01,Sub_95_SP01, alpha=.5, linewidth=0,label="95% CI")
ax[0,0].plot(time,Sub_mean_SP01, linewidth=2,label="Mean")
ax[0,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,0].set_ylim([0, 0.85])
ax[0,0].set_title('SP1')
ax[0,1].fill_between(time,Sub_5_SP02,Sub_95_SP02, alpha=.5, linewidth=0,label="95% CI")
ax[0,1].plot(time,Sub_mean_SP02, linewidth=2,label="Mean")
ax[0,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,1].set_ylim([0, 0.85])
ax[0,1].set_title('SP2')
ax[0,2].fill_between(time,Sub_5_SP03,Sub_95_SP03, alpha=.5, linewidth=0,label="95% CI")
ax[0,2].plot(time,Sub_mean_SP03, linewidth=2,label="Mean")
ax[0,2].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,2].set_ylim([0, 0.85])
ax[0,2].set_title('SP3')
ax[1,0].fill_between(time,Sub_5_SP04,Sub_95_SP04, alpha=.5, linewidth=0,label="95% CI")
ax[1,0].plot(time,Sub_mean_SP04, linewidth=2,label="Mean")
ax[1,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,0].set_ylim([0, 0.85])
ax[1,0].set_title('SP4')
ax[1,1].fill_between(time,Sub_5_SP05,Sub_95_SP05, alpha=.5, linewidth=0,label="95% CI")
ax[1,1].plot(time,Sub_mean_SP05, linewidth=2,label="Mean")
ax[1,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,1].set_ylim([0, 0.85])
ax[1,1].set_title('SP5')
fig.text(0.5, -0.02, 'Time (d)', ha='center', va='center')
fig.text(0.06, 0.5, '$NH_4$ ($mg$ $cm^{-3}$)', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.06, 0.5, '$NH_4$ ($mg$ $cm^{-3}$)')

# %% [markdown]
# ### PO4

# %%
SP01_cue = []
SP02_cue = []
SP03_cue = []
SP04_cue = []
SP05_cue = []

for i in tt:
        SP01_cue.append(SP01[int(i)].PO4Series)
        SP02_cue.append(SP02[int(i)].PO4Series)
        SP03_cue.append(SP03[int(i)].PO4Series)
        SP04_cue.append(SP04[int(i)].PO4Series)
        SP05_cue.append(SP05[int(i)].PO4Series)

# %%
Sub_mean_SP01  = (np.array(SP01_cue).mean(axis=0))/10000
Sub_5_SP01     = np.percentile(SP01_cue,5,axis=0)/10000
Sub_95_SP01    = np.percentile(SP01_cue,95,axis=0)/10000
Sub_mean_SP02  = (np.array(SP02_cue).mean(axis=0))/10000
Sub_5_SP02     = np.percentile(SP02_cue,5,axis=0)/10000
Sub_95_SP02    = np.percentile(SP02_cue,95,axis=0)/10000
Sub_mean_SP03  = (np.array(SP03_cue).mean(axis=0))/10000
Sub_5_SP03     = np.percentile(SP03_cue,5,axis=0)/10000
Sub_95_SP03    = np.percentile(SP03_cue,95,axis=0)/10000
Sub_mean_SP04  = (np.array(SP04_cue).mean(axis=0))/10000
Sub_5_SP04     = np.percentile(SP04_cue,5,axis=0)/10000
Sub_95_SP04    = np.percentile(SP04_cue,95,axis=0)/10000
Sub_mean_SP05  = (np.array(SP05_cue).mean(axis=0))/10000
Sub_5_SP05     = np.percentile(SP05_cue,5,axis=0)/10000
Sub_95_SP05    = np.percentile(SP05_cue,95,axis=0)/10000

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row', figsize = (6,3), dpi = 140)
ax[0,0].fill_between(time,Sub_5_SP01,Sub_95_SP01, alpha=.5, linewidth=0,label="95% CI")
ax[0,0].plot(time,Sub_mean_SP01, linewidth=2,label="Mean")
ax[0,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,0].set_ylim([0, 0.85])
ax[0,0].set_title('SP1')
ax[0,1].fill_between(time,Sub_5_SP02,Sub_95_SP02, alpha=.5, linewidth=0,label="95% CI")
ax[0,1].plot(time,Sub_mean_SP02, linewidth=2,label="Mean")
ax[0,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,1].set_ylim([0, 0.85])
ax[0,1].set_title('SP2')
ax[0,2].fill_between(time,Sub_5_SP03,Sub_95_SP03, alpha=.5, linewidth=0,label="95% CI")
ax[0,2].plot(time,Sub_mean_SP03, linewidth=2,label="Mean")
ax[0,2].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,2].set_ylim([0, 0.85])
ax[0,2].set_title('SP3')
ax[1,0].fill_between(time,Sub_5_SP04,Sub_95_SP04, alpha=.5, linewidth=0,label="95% CI")
ax[1,0].plot(time,Sub_mean_SP04, linewidth=2,label="Mean")
ax[1,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,0].set_ylim([0, 0.85])
ax[1,0].set_title('SP4')
ax[1,1].fill_between(time,Sub_5_SP05,Sub_95_SP05, alpha=.5, linewidth=0,label="95% CI")
ax[1,1].plot(time,Sub_mean_SP05, linewidth=2,label="Mean")
ax[1,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,1].set_ylim([0, 0.85])
ax[1,1].set_title('SP5')
fig.text(0.5, -0.02, 'Time (d)', ha='center', va='center')
fig.text(0.06, 0.5, '$PO_4$ ($mg$ $cm^{-3}$)', ha='center', va='center', rotation='vertical')
# Out:
# Text(0.06, 0.5, '$PO_4$ ($mg$ $cm^{-3}$)')

# %% [markdown]
# ### Osmolythe cost

# %%
cost_osmo_SP1 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP1      = {}
cost_osmo_SP2 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP2      = {}
cost_osmo_SP3 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP3      = {}
cost_osmo_SP4 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP4      = {}
cost_osmo_SP5 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP5      = {}
for i in tt:
  cost_osmo_SP1["Run"+str(int(i)+1)] = (SP01[int(i)].Initialization['OsmoProdConsti_trait']+SP01[int(i)].Initialization['OsmoProdInduci_trait'])*(SP01[int(i)].Initialization['OsmoGenes'].sum(axis=1))
  biom_SP1["Run"+str(int(i)+1)] = (SP01[int(i)].MicrobesSeries)/(SP01[int(i)].MicrobesSeries).sum(axis=0)
  cost_osmo_SP2["Run"+str(int(i)+1)] = (SP02[int(i)].Initialization['OsmoProdConsti_trait']+SP02[int(i)].Initialization['OsmoProdInduci_trait'])*(SP02[int(i)].Initialization['OsmoGenes'].sum(axis=1))
  biom_SP2["Run"+str(int(i)+1)] = (SP02[int(i)].MicrobesSeries)/(SP02[int(i)].MicrobesSeries).sum(axis=0)
  cost_osmo_SP3["Run"+str(int(i)+1)] = (SP03[int(i)].Initialization['OsmoProdConsti_trait']+SP03[int(i)].Initialization['OsmoProdInduci_trait'])*(SP03[int(i)].Initialization['OsmoGenes'].sum(axis=1))
  biom_SP3["Run"+str(int(i)+1)] = (SP03[int(i)].MicrobesSeries)/(SP03[int(i)].MicrobesSeries).sum(axis=0)
  cost_osmo_SP4["Run"+str(int(i)+1)] = (SP04[int(i)].Initialization['OsmoProdConsti_trait']+SP04[int(i)].Initialization['OsmoProdInduci_trait'])*(SP04[int(i)].Initialization['OsmoGenes'].sum(axis=1))
  biom_SP4["Run"+str(int(i)+1)] = (SP04[int(i)].MicrobesSeries)/(SP04[int(i)].MicrobesSeries).sum(axis=0)
  cost_osmo_SP5["Run"+str(int(i)+1)] = (SP05[int(i)].Initialization['OsmoProdConsti_trait']+SP05[int(i)].Initialization['OsmoProdInduci_trait'])*(SP05[int(i)].Initialization['OsmoGenes'].sum(axis=1))
  biom_SP5["Run"+str(int(i)+1)] = (SP05[int(i)].MicrobesSeries)/(SP05[int(i)].MicrobesSeries).sum(axis=0)

# %%
osmo_cost_SP1 = []
osmo_cost_SP2 = []
osmo_cost_SP3 = []
osmo_cost_SP4 = []
osmo_cost_SP5 = []
for i in tt:
    osmo_cost_SP1.append((biom_SP1["Run"+str(int(i)+1)].mul(cost_osmo_SP1["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    osmo_cost_SP2.append((biom_SP2["Run"+str(int(i)+1)].mul(cost_osmo_SP2["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    osmo_cost_SP3.append((biom_SP3["Run"+str(int(i)+1)].mul(cost_osmo_SP3["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    osmo_cost_SP4.append((biom_SP4["Run"+str(int(i)+1)].mul(cost_osmo_SP4["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    osmo_cost_SP5.append((biom_SP5["Run"+str(int(i)+1)].mul(cost_osmo_SP5["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))

# %%
osmo_cost_SP1_mean  = (np.array(osmo_cost_SP1).mean(axis=0))
osmo_cost_SP1_5     = np.percentile(osmo_cost_SP1,5,axis=0)
osmo_cost_SP1_95    = np.percentile(osmo_cost_SP1,95,axis=0)
osmo_cost_SP2_mean  = (np.array(osmo_cost_SP2).mean(axis=0))
osmo_cost_SP2_5     = np.percentile(osmo_cost_SP2,5,axis=0)
osmo_cost_SP2_95    = np.percentile(osmo_cost_SP2,95,axis=0)
osmo_cost_SP3_mean  = (np.array(osmo_cost_SP3).mean(axis=0))
osmo_cost_SP3_5     = np.percentile(osmo_cost_SP3,5,axis=0)
osmo_cost_SP3_95    = np.percentile(osmo_cost_SP3,95,axis=0)
osmo_cost_SP4_mean  = (np.array(osmo_cost_SP4).mean(axis=0))
osmo_cost_SP4_5     = np.percentile(osmo_cost_SP4,5,axis=0)
osmo_cost_SP4_95    = np.percentile(osmo_cost_SP4,95,axis=0)
osmo_cost_SP5_mean  = (np.array(osmo_cost_SP5).mean(axis=0))
osmo_cost_SP5_5     = np.percentile(osmo_cost_SP5,5,axis=0)
osmo_cost_SP5_95    = np.percentile(osmo_cost_SP5,95,axis=0)

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row', figsize = (6,3), dpi = 140)
ax[0,0].fill_between(time,osmo_cost_SP1_5,osmo_cost_SP1_95, alpha=.5, linewidth=0,label="95% CI")
ax[0,0].plot(time,osmo_cost_SP1_mean, linewidth=2,label="Mean")
ax[0,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,0].set_ylim([0, 0.0125])
ax[0,0].set_title('SP1')
ax[0,1].fill_between(time,osmo_cost_SP2_5,osmo_cost_SP2_95, alpha=.5, linewidth=0,label="95% CI")
ax[0,1].plot(time,osmo_cost_SP2_mean, linewidth=2,label="Mean")
ax[0,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,1].set_ylim([0, 0.0125])
ax[0,1].set_title('SP2')
ax[0,2].fill_between(time,osmo_cost_SP3_5,osmo_cost_SP3_95, alpha=.5, linewidth=0,label="95% CI")
ax[0,2].plot(time,osmo_cost_SP3_mean, linewidth=2,label="Mean")
ax[0,2].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,2].set_ylim([0, 0.0125])
ax[0,2].set_title('SP3')
ax[1,0].fill_between(time,osmo_cost_SP4_5,osmo_cost_SP4_95, alpha=.5, linewidth=0,label="95% CI")
ax[1,0].plot(time,osmo_cost_SP4_mean, linewidth=2,label="Mean")
ax[1,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,0].set_ylim([0, 0.0125])
ax[1,0].set_title('SP4')
ax[1,1].fill_between(time,osmo_cost_SP5_5,osmo_cost_SP5_95, alpha=.5, linewidth=0,label="95% CI")
ax[1,1].plot(time,osmo_cost_SP5_mean, linewidth=2,label="Mean")
ax[1,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,1].set_ylim([0, 0.0125])
ax[1,1].set_title('SP5')
fig.text(0.5, -0.02, 'Time (d)', ha='center', va='center')
fig.text(0.06, 0.5, 'Osmolyte investment', ha='center', va='center', rotation='vertical')
fig.subplots_adjust(left=0.18)

# %% [markdown]
# ### Enzyme cost

# %%
enzy_osmo_SP1 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP1      = {}
enzy_osmo_SP2 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP2      = {}
enzy_osmo_SP3 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP3      = {}
enzy_osmo_SP4 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP4      = {}
enzy_osmo_SP5 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP5      = {}
for i in tt:
  enzy_osmo_SP1["Run"+str(int(i)+1)] = (SP01[int(i)].Initialization['EnzProdConsti_trait']+SP01[int(i)].Initialization['EnzProdInduci_trait'])*(SP01[int(i)].Initialization['EnzGenes'].sum(axis=1))
  biom_SP1["Run"+str(int(i)+1)] = (SP01[int(i)].MicrobesSeries)/(SP01[int(i)].MicrobesSeries).sum(axis=0)
  enzy_osmo_SP2["Run"+str(int(i)+1)] = (SP02[int(i)].Initialization['EnzProdConsti_trait']+SP02[int(i)].Initialization['EnzProdInduci_trait'])*(SP02[int(i)].Initialization['EnzGenes'].sum(axis=1))
  biom_SP2["Run"+str(int(i)+1)] = (SP02[int(i)].MicrobesSeries)/(SP02[int(i)].MicrobesSeries).sum(axis=0)
  enzy_osmo_SP3["Run"+str(int(i)+1)] = (SP03[int(i)].Initialization['EnzProdConsti_trait']+SP03[int(i)].Initialization['EnzProdInduci_trait'])*(SP03[int(i)].Initialization['EnzGenes'].sum(axis=1))
  biom_SP3["Run"+str(int(i)+1)] = (SP03[int(i)].MicrobesSeries)/(SP03[int(i)].MicrobesSeries).sum(axis=0)
  enzy_osmo_SP4["Run"+str(int(i)+1)] = (SP04[int(i)].Initialization['EnzProdConsti_trait']+SP04[int(i)].Initialization['EnzProdInduci_trait'])*(SP04[int(i)].Initialization['EnzGenes'].sum(axis=1))
  biom_SP4["Run"+str(int(i)+1)] = (SP04[int(i)].MicrobesSeries)/(SP04[int(i)].MicrobesSeries).sum(axis=0)
  enzy_osmo_SP5["Run"+str(int(i)+1)] = (SP05[int(i)].Initialization['EnzProdConsti_trait']+SP05[int(i)].Initialization['EnzProdInduci_trait'])*(SP05[int(i)].Initialization['EnzGenes'].sum(axis=1))
  biom_SP5["Run"+str(int(i)+1)] = (SP05[int(i)].MicrobesSeries)/(SP05[int(i)].MicrobesSeries).sum(axis=0)

# %%
enzy_cost_SP1 = []
enzy_cost_SP2 = []
enzy_cost_SP3 = []
enzy_cost_SP4 = []
enzy_cost_SP5 = []
for i in tt:
    enzy_cost_SP1.append((biom_SP1["Run"+str(int(i)+1)].mul(enzy_osmo_SP1["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    enzy_cost_SP2.append((biom_SP2["Run"+str(int(i)+1)].mul(enzy_osmo_SP2["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    enzy_cost_SP3.append((biom_SP3["Run"+str(int(i)+1)].mul(enzy_osmo_SP3["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    enzy_cost_SP4.append((biom_SP4["Run"+str(int(i)+1)].mul(enzy_osmo_SP4["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    enzy_cost_SP5.append((biom_SP5["Run"+str(int(i)+1)].mul(enzy_osmo_SP5["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))

# %%
enzy_cost_SP1_mean  = (np.array(enzy_cost_SP1).mean(axis=0))
enzy_cost_SP1_5     = np.percentile(enzy_cost_SP1,5,axis=0)
enzy_cost_SP1_95    = np.percentile(enzy_cost_SP1,95,axis=0)
enzy_cost_SP2_mean  = (np.array(enzy_cost_SP2).mean(axis=0))
enzy_cost_SP2_5     = np.percentile(enzy_cost_SP2,5,axis=0)
enzy_cost_SP2_95    = np.percentile(enzy_cost_SP2,95,axis=0)
enzy_cost_SP3_mean  = (np.array(enzy_cost_SP3).mean(axis=0))
enzy_cost_SP3_5     = np.percentile(enzy_cost_SP3,5,axis=0)
enzy_cost_SP3_95    = np.percentile(enzy_cost_SP3,95,axis=0)
enzy_cost_SP4_mean  = (np.array(enzy_cost_SP4).mean(axis=0))
enzy_cost_SP4_5     = np.percentile(enzy_cost_SP4,5,axis=0)
enzy_cost_SP4_95    = np.percentile(enzy_cost_SP4,95,axis=0)
enzy_cost_SP5_mean  = (np.array(enzy_cost_SP5).mean(axis=0))
enzy_cost_SP5_5     = np.percentile(enzy_cost_SP5,5,axis=0)
enzy_cost_SP5_95    = np.percentile(enzy_cost_SP5,95,axis=0)

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row', figsize = (6,3), dpi = 140)
ax[0,0].fill_between(time,enzy_cost_SP1_5,enzy_cost_SP1_95, alpha=.5, linewidth=0,label="95% CI")
ax[0,0].plot(time,enzy_cost_SP1_mean, linewidth=2,label="Mean")
ax[0,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,0].set_ylim([0, 0.0025])
ax[0,0].set_title('SP1')
ax[0,1].fill_between(time,enzy_cost_SP2_5,enzy_cost_SP2_95, alpha=.5, linewidth=0,label="95% CI")
ax[0,1].plot(time,enzy_cost_SP2_mean, linewidth=2,label="Mean")
ax[0,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,1].set_ylim([0, 0.0025])
ax[0,1].set_title('SP2')
ax[0,2].fill_between(time,enzy_cost_SP3_5,enzy_cost_SP3_95, alpha=.5, linewidth=0,label="95% CI")
ax[0,2].plot(time,enzy_cost_SP3_mean, linewidth=2,label="Mean")
ax[0,2].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[0,2].set_ylim([0, 0.0025])
ax[0,2].set_title('SP3')
ax[1,0].fill_between(time,enzy_cost_SP4_5,enzy_cost_SP4_95, alpha=.5, linewidth=0,label="95% CI")
ax[1,0].plot(time,enzy_cost_SP4_mean, linewidth=2,label="Mean")
ax[1,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,0].set_ylim([0, 0.0025])
ax[1,0].set_title('SP4')
ax[1,1].fill_between(time,enzy_cost_SP5_5,enzy_cost_SP5_95, alpha=.5, linewidth=0,label="95% CI")
ax[1,1].plot(time,enzy_cost_SP5_mean, linewidth=2,label="Mean")
ax[1,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
ax[1,1].set_ylim([0, 0.0025])
ax[1,1].set_title('SP5')
fig.text(0.5, -0.02, 'Time (d)', ha='center', va='center')
fig.text(0.06, 0.5, 'Enzyme investment', ha='center', va='center', rotation='vertical')
fig.subplots_adjust(left=0.18)

# %% [markdown]
# ### Transporter cost

# %%
trans_osmo_SP1 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP1      = {}
trans_osmo_SP2 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP2      = {}
trans_osmo_SP3 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP3      = {}
trans_osmo_SP4 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP4      = {}
trans_osmo_SP5 = {} # Cost of osmolythe (consti + inducible) times number of osmolythes per taxa
biom_SP5      = {}
for i in tt:
  trans_osmo_SP1["Run"+str(int(i)+1)] = (SP01[int(i)].Initialization['UptakeGenes_trait'])*(SP01[int(i)].Initialization['UptakeGenes'].sum(axis=1))
  biom_SP1["Run"+str(int(i)+1)] = (SP01[int(i)].MicrobesSeries)/(SP01[int(i)].MicrobesSeries).sum(axis=0)
  trans_osmo_SP2["Run"+str(int(i)+1)] = (SP02[int(i)].Initialization['UptakeGenes_trait'])*(SP02[int(i)].Initialization['UptakeGenes'].sum(axis=1))
  biom_SP2["Run"+str(int(i)+1)] = (SP02[int(i)].MicrobesSeries)/(SP02[int(i)].MicrobesSeries).sum(axis=0)
  trans_osmo_SP3["Run"+str(int(i)+1)] = (SP03[int(i)].Initialization['UptakeGenes_trait'])*(SP03[int(i)].Initialization['UptakeGenes'].sum(axis=1))
  biom_SP3["Run"+str(int(i)+1)] = (SP03[int(i)].MicrobesSeries)/(SP03[int(i)].MicrobesSeries).sum(axis=0)
  trans_osmo_SP4["Run"+str(int(i)+1)] = (SP04[int(i)].Initialization['UptakeGenes_trait'])*(SP04[int(i)].Initialization['UptakeGenes'].sum(axis=1))
  biom_SP4["Run"+str(int(i)+1)] = (SP04[int(i)].MicrobesSeries)/(SP04[int(i)].MicrobesSeries).sum(axis=0)
  trans_osmo_SP5["Run"+str(int(i)+1)] = (SP05[int(i)].Initialization['UptakeGenes_trait'])*(SP05[int(i)].Initialization['UptakeGenes'].sum(axis=1))
  biom_SP5["Run"+str(int(i)+1)] = (SP05[int(i)].MicrobesSeries)/(SP05[int(i)].MicrobesSeries).sum(axis=0)

# %%
trans_cost_SP1 = []
trans_cost_SP2 = []
trans_cost_SP3 = []
trans_cost_SP4 = []
trans_cost_SP5 = []
for i in tt:
    trans_cost_SP1.append((biom_SP1["Run"+str(int(i)+1)].mul(trans_osmo_SP1["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    trans_cost_SP2.append((biom_SP2["Run"+str(int(i)+1)].mul(trans_osmo_SP2["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    trans_cost_SP3.append((biom_SP3["Run"+str(int(i)+1)].mul(trans_osmo_SP3["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    trans_cost_SP4.append((biom_SP4["Run"+str(int(i)+1)].mul(trans_osmo_SP4["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))
    trans_cost_SP5.append((biom_SP5["Run"+str(int(i)+1)].mul(trans_osmo_SP5["Run"+str(int(i)+1)][0:100], axis=0)).sum(axis=0))

# %%
trans_cost_SP1_mean  = (np.array(trans_cost_SP1).mean(axis=0))
trans_cost_SP1_5     = np.percentile(trans_cost_SP1,5,axis=0)
trans_cost_SP1_95    = np.percentile(trans_cost_SP1,95,axis=0)
trans_cost_SP2_mean  = (np.array(trans_cost_SP2).mean(axis=0))
trans_cost_SP2_5     = np.percentile(trans_cost_SP2,5,axis=0)
trans_cost_SP2_95    = np.percentile(trans_cost_SP2,95,axis=0)
trans_cost_SP3_mean  = (np.array(trans_cost_SP3).mean(axis=0))
trans_cost_SP3_5     = np.percentile(trans_cost_SP3,5,axis=0)
trans_cost_SP3_95    = np.percentile(trans_cost_SP3,95,axis=0)
trans_cost_SP4_mean  = (np.array(trans_cost_SP4).mean(axis=0))
trans_cost_SP4_5     = np.percentile(trans_cost_SP4,5,axis=0)
trans_cost_SP4_95    = np.percentile(trans_cost_SP4,95,axis=0)
trans_cost_SP5_mean  = (np.array(trans_cost_SP5).mean(axis=0))
trans_cost_SP5_5     = np.percentile(trans_cost_SP5,5,axis=0)
trans_cost_SP5_95    = np.percentile(trans_cost_SP5,95,axis=0)

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row', figsize = (6,3), dpi = 140)
ax[0,0].fill_between(time,trans_cost_SP1_5,trans_cost_SP1_95, alpha=.5, linewidth=0,label="95% CI")
ax[0,0].plot(time,trans_cost_SP1_mean, linewidth=2,label="Mean")
ax[0,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
#ax[0,0].set_ylim([0, 0.0025])
ax[0,0].set_title('SP1')
ax[0,1].fill_between(time,trans_cost_SP2_5,trans_cost_SP2_95, alpha=.5, linewidth=0,label="95% CI")
ax[0,1].plot(time,trans_cost_SP2_mean, linewidth=2,label="Mean")
ax[0,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
#ax[0,1].set_ylim([0, 0.0025])
ax[0,1].set_title('SP2')
ax[0,2].fill_between(time,trans_cost_SP3_5,trans_cost_SP3_95, alpha=.5, linewidth=0,label="95% CI")
ax[0,2].plot(time,trans_cost_SP3_mean, linewidth=2,label="Mean")
ax[0,2].axvline(x = 365*3, color = 'r', label = 'Traslocation')
#ax[0,2].set_ylim([0, 0.0025])
ax[0,2].set_title('SP3')
ax[1,0].fill_between(time,trans_cost_SP4_5,trans_cost_SP4_95, alpha=.5, linewidth=0,label="95% CI")
ax[1,0].plot(time,trans_cost_SP4_mean, linewidth=2,label="Mean")
ax[1,0].axvline(x = 365*3, color = 'r', label = 'Traslocation')
#ax[1,0].set_ylim([0, 0.0025])
ax[1,0].set_title('SP4')
ax[1,1].fill_between(time,trans_cost_SP5_5,trans_cost_SP5_95, alpha=.5, linewidth=0,label="95% CI")
ax[1,1].plot(time,trans_cost_SP5_mean, linewidth=2,label="Mean")
ax[1,1].axvline(x = 365*3, color = 'r', label = 'Traslocation')
#ax[1,1].set_ylim([0, 0.0025])
ax[1,1].set_title('SP5')
fig.text(0.5, -0.02, 'Time (d)', ha='center', va='center')
fig.text(0.06, 0.5, 'Transporter investment', ha='center', va='center', rotation='vertical')
fig.subplots_adjust(left=0.15)
